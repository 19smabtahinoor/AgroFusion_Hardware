# %% [markdown]
# # Initialize constants

# %% [markdown]
# Set BASE_MODEL according to [Pretrained Checkpoints](https://github.com/ultralytics/yolov5/releases)

# %%
PROJECT_NAME = "yolov5_train"
BASE_MODEL = "yolov5m6.pt"
TRAIN_BATCH = 80
TRAIN_EPOCHS = 100
VAL_BATCH = 64
print('Initializtion Done!')
# Out:
# Initializtion Done!

# %% [markdown]
# # Clone yolov5 repo

# %%
# !rm -rf /kaggle/working/yolov5
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16525, done.
# remote: Total 16525 (delta 0), reused 0 (delta 0), pack-reused 16525
# Receiving objects: 100% (16525/16525), 15.00 MiB | 25.56 MiB/s, done.
# Resolving deltas: 100% (11361/11361), done.

# %%
# %cd /kaggle/working/yolov5
# !pip install -r requirements.txt
# Out:
# /kaggle/working/yolov5
# Requirement already satisfied: gitpython>=3.1.30 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (3.1.41)
# Requirement already satisfied: matplotlib>=3.3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (3.7.5)
# Requirement already satisfied: numpy>=1.23.5 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (1.26.4)
# Requirement already satisfied: opencv-python>=4.1.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (4.9.0.80)
# Requirement already satisfied: Pillow>=9.4.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (9.5.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (5.9.3)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (1.11.4)
# Collecting thop>=0.1.1 (from -r requirements.txt (line 14))
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (2.1.2)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (0.16.2)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (4.66.1)
# Collecting ultralytics>=8.0.232 (from -r requirements.txt (line 18))
#   Downloading ultralytics-8.1.43-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 27)) (2.1.4)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 28)) (0.12.2)
# Requirement already satisfied: setuptools>=65.5.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 42)) (69.0.3)
# Requirement already satisfied: wheel>=0.38.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 50)) (0.42.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.11)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (2024.2.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2024.3.0)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics>=8.0.232->-r requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2023.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading ultralytics-8.1.43-py3-none-any.whl (749 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.5/749.5 kB 24.0 MB/s eta 0:00:00
# Installing collected packages: thop, ultralytics
# Successfully installed thop-0.1.1.post2209072238 ultralytics-8.1.43

# %% [markdown]
# # Import libraries

# %% [markdown]
# This notebook contains steps to train and evaluate yolov5 model with custom data from scratch.
#
# Steps to reproduce:
# 1. Collect lots of images.
# 2. Label images using labeling tool.
# 4. Train model and get weights file.
# 5. Initialize model with weights file & use it.

# %%
import torch
from yolov5 import utils
import torch
from IPython import display
from IPython.display import clear_output
from pathlib import Path
import yaml
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import io
import os
import cv2
import json
import shutil
import numpy as np
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %% [markdown]
# # Convert data to yolov5 Pytorch format
#
# Prepare data from Label Studio yolov5 darknet format to pytorch yolov5

# %%
IMAGES_PATH = "/kaggle/input/plant-disease-dataset/images"
LABELS_PATH = "/kaggle/input/plant-disease-dataset/labels"
NOTES_PATH = "/kaggle/input/plant-disease-dataset/notes.json"

# %%
# Read labels
labels = os.listdir(LABELS_PATH)

# Split data
train, test = train_test_split(labels, test_size=0.15, shuffle=True)
valid, test = train_test_split(test, test_size=0.2)

print(f"train: {len(train)}; valid: {len(valid)}; test: {len(test)}")
# Out:
# train: 6784; valid: 958; test: 240

# %% [markdown]
# Make dirs for pytorch dataset format

# %%
os.makedirs("test/images")
os.makedirs("test/labels")
os.makedirs("train/images")
os.makedirs("train/labels")
os.makedirs("valid/images")
os.makedirs("valid/labels")

# %%
def move_files_to_dir(files, dirname):
    for label_filename in files:
        image_filename = f"{label_filename[:-4]}.jpg"
        shutil.copy(f"{IMAGES_PATH}/{image_filename}", f"{dirname}/images/{image_filename}")
        shutil.copy(f"{LABELS_PATH}/{label_filename}", f"{dirname}/labels/{label_filename}")

# Move splits to folders
move_files_to_dir(train, "train")
move_files_to_dir(test, "test")
move_files_to_dir(valid, "valid")

# %% [markdown]
# Convert yolov5-darknet to yolov5-pytorch description file

# %%
descr_darknet = json.load(open(NOTES_PATH))

train_path = "../train/images"
test_path = "../test/images"
valid_path = "../valid/images"

nc = len(descr_darknet["categories"])
names = [category["name"] for category in descr_darknet["categories"]]

print(
    f"train: {train_path}\n"
    f"test: {test_path}\n"
    f"val: {valid_path}\n\n"
    f"nc: {nc}\n"
    f"names: {names}",
)
# Out:
# train: ../train/images
# test: ../test/images
# val: ../valid/images
#
# nc: 20
# names: ['chilli antracnose', 'chilli bacterial leaf spot', 'chilli mosaic leaf virus', 'eggplant cercospora leaf spot', 'eggplant colorado potato beetle', 'eggplant fruit rot', 'eggplant fuit rot', 'eggplant healthy fruit', 'eggplant healthy leaf', 'healthy chilli leaf', 'healthy chilli', 'potato alternaria solani leaf', 'potato common scab fruit', 'potato healthy fruit', 'potato healthy leaf', 'potato pythopthora infestans leaf', 'tomato antracnose', 'tomato bacterial spot', 'tomato healthy', 'tomato late blight leaf']

# %%
with open("data.yaml", "w") as file:
    yaml.dump({
        "train": train_path,
        "test": test_path,
        "val": valid_path,
        "nc": nc,
        "names": [f'{name}' for name in names]
    }, stream=file, default_flow_style=None)

# %%
print("Now we are ready to train yolov5 model")
! ls
# Out:
# Now we are ready to train yolov5 model
# CITATION.cff	 benchmarks.py	export.py	  segment	  utils
# CONTRIBUTING.md  classify	hubconf.py	  test		  val.py
# LICENSE		 data		models		  train		  valid
# README.md	 data.yaml	pyproject.toml	  train.py
# README.zh-CN.md  detect.py	requirements.txt  tutorial.ipynb

# %% [markdown]
# # Train yolov5

# %%
# !python train.py --batch-size $TRAIN_BATCH --epochs $TRAIN_EPOCHS --data "data.yaml" --weights $BASE_MODEL --project $PROJECT_NAME --name 'feature_extraction' --cache --freeze 12
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2024-04-06 14:56:07.292932: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-06 14:56:07.293055: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-06 14:56:07.427858: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# train: weights=yolov5m6.pt, cfg=, data=data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=80, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5_train, name=feature_extraction, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[12], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-295-gac6c4383 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir yolov5_train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 22.3MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5m6.pt to yolov5m6.pt...
# 100%|███████████████████████████████████████| 69.0M/69.0M [00:00<00:00, 252MB/s]
#
# Overriding model.yaml nc=80 with nc=20
#
#                  from  n    params  module                                  arguments
#   0                -1  1      5280  models.common.Conv                      [3, 48, 6, 2, 2]
#   1                -1  1     41664  models.common.Conv                      [48, 96, 3, 2]
#   2                -1  2     65280  models.common.C3                        [96, 96, 2]
#   3                -1  1    166272  models.common.Conv                      [96, 192, 3, 2]
#   4                -1  4    444672  models.common.C3                        [192, 192, 4]
#   5                -1  1    664320  models.common.Conv                      [192, 384, 3, 2]
#   6                -1  6   2512896  models.common.C3                        [384, 384, 6]
#   7                -1  1   1991808  models.common.Conv                      [384, 576, 3, 2]
#   8                -1  2   2327040  models.common.C3                        [576, 576, 2]
#   9                -1  1   3982848  models.common.Conv                      [576, 768, 3, 2]
#  10                -1  2   4134912  models.common.C3                        [768, 768, 2]
#  11                -1  1   1476864  models.common.SPPF                      [768, 768, 5]
#  12                -1  1    443520  models.common.Conv                      [768, 576, 1, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 8]  1         0  models.common.Concat                    [1]
#  15                -1  2   2658816  models.common.C3                        [1152, 576, 2, False]
#  16                -1  1    221952  models.common.Conv                      [576, 384, 1, 1]
#  17                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  18           [-1, 6]  1         0  models.common.Concat                    [1]
#  19                -1  2   1182720  models.common.C3                        [768, 384, 2, False]
#  20                -1  1     74112  models.common.Conv                      [384, 192, 1, 1]
#  21                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  22           [-1, 4]  1         0  models.common.Concat                    [1]
#  23                -1  2    296448  models.common.C3                        [384, 192, 2, False]
#  24                -1  1    332160  models.common.Conv                      [192, 192, 3, 2]
#  25          [-1, 20]  1         0  models.common.Concat                    [1]
#  26                -1  2   1035264  models.common.C3                        [384, 384, 2, False]
#  27                -1  1   1327872  models.common.Conv                      [384, 384, 3, 2]
#  28          [-1, 16]  1         0  models.common.Concat                    [1]
#  29                -1  2   2437632  models.common.C3                        [768, 576, 2, False]
#  30                -1  1   2987136  models.common.Conv                      [576, 576, 3, 2]
#  31          [-1, 12]  1         0  models.common.Concat                    [1]
#  32                -1  2   4429824  models.common.C3                        [1152, 768, 2, False]
#  33  [23, 26, 29, 32]  1    144300  models.yolo.Detect                      [20, [[19, 27, 44, 40, 38, 94], [96, 68, 86, 152, 180, 137], [140, 301, 303, 264, 238, 542], [436, 615, 739, 380, 925, 792]], [192, 384, 576, 768]]
# Model summary: 379 layers, 35385612 parameters, 35385612 gradients, 49.5 GFLOPs
#
# Transferred 619/627 items from yolov5m6.pt
# AMP: checks passed ✅
# freezing model.0.conv.weight
# freezing model.0.bn.weight
# freezing model.0.bn.bias
# freezing model.1.conv.weight
# freezing model.1.bn.weight
# freezing model.1.bn.bias
# freezing model.2.cv1.conv.weight
# freezing model.2.cv1.bn.weight
# freezing model.2.cv1.bn.bias
# freezing model.2.cv2.conv.weight
# freezing model.2.cv2.bn.weight
# freezing model.2.cv2.bn.bias
# freezing model.2.cv3.conv.weight
# freezing model.2.cv3.bn.weight
# freezing model.2.cv3.bn.bias
# freezing model.2.m.0.cv1.conv.weight
# freezing model.2.m.0.cv1.bn.weight
# freezing model.2.m.0.cv1.bn.bias
# freezing model.2.m.0.cv2.conv.weight
# freezing model.2.m.0.cv2.bn.weight
# freezing model.2.m.0.cv2.bn.bias
# freezing model.2.m.1.cv1.conv.weight
# freezing model.2.m.1.cv1.bn.weight
# freezing model.2.m.1.cv1.bn.bias
# freezing model.2.m.1.cv2.conv.weight
# freezing model.2.m.1.cv2.bn.weight
# freezing model.2.m.1.cv2.bn.bias
# freezing model.3.conv.weight
# freezing model.3.bn.weight
# freezing model.3.bn.bias
# freezing model.4.cv1.conv.weight
# freezing model.4.cv1.bn.weight
# freezing model.4.cv1.bn.bias
# freezing model.4.cv2.conv.weight
# freezing model.4.cv2.bn.weight
# freezing model.4.cv2.bn.bias
# freezing model.4.cv3.conv.weight
# freezing model.4.cv3.bn.weight
# freezing model.4.cv3.bn.bias
# freezing model.4.m.0.cv1.conv.weight
# freezing model.4.m.0.cv1.bn.weight
# freezing model.4.m.0.cv1.bn.bias
# freezing model.4.m.0.cv2.conv.weight
# freezing model.4.m.0.cv2.bn.weight
# freezing model.4.m.0.cv2.bn.bias
# freezing model.4.m.1.cv1.conv.weight
# freezing model.4.m.1.cv1.bn.weight
# freezing model.4.m.1.cv1.bn.bias
# freezing model.4.m.1.cv2.conv.weight
# freezing model.4.m.1.cv2.bn.weight
# freezing model.4.m.1.cv2.bn.bias
# freezing model.4.m.2.cv1.conv.weight
# freezing model.4.m.2.cv1.bn.weight
# freezing model.4.m.2.cv1.bn.bias
# freezing model.4.m.2.cv2.conv.weight
# freezing model.4.m.2.cv2.bn.weight
# freezing model.4.m.2.cv2.bn.bias
# freezing model.4.m.3.cv1.conv.weight
# freezing model.4.m.3.cv1.bn.weight
# freezing model.4.m.3.cv1.bn.bias
# freezing model.4.m.3.cv2.conv.weight
# freezing model.4.m.3.cv2.bn.weight
# freezing model.4.m.3.cv2.bn.bias
# freezing model.5.conv.weight
# freezing model.5.bn.weight
# freezing model.5.bn.bias
# freezing model.6.cv1.conv.weight
# freezing model.6.cv1.bn.weight
# freezing model.6.cv1.bn.bias
# freezing model.6.cv2.conv.weight
# freezing model.6.cv2.bn.weight
# freezing model.6.cv2.bn.bias
# freezing model.6.cv3.conv.weight
# freezing model.6.cv3.bn.weight
# freezing model.6.cv3.bn.bias
# freezing model.6.m.0.cv1.conv.weight
# freezing model.6.m.0.cv1.bn.weight
# freezing model.6.m.0.cv1.bn.bias
# freezing model.6.m.0.cv2.conv.weight
# freezing model.6.m.0.cv2.bn.weight
# freezing model.6.m.0.cv2.bn.bias
# freezing model.6.m.1.cv1.conv.weight
# freezing model.6.m.1.cv1.bn.weight
# freezing model.6.m.1.cv1.bn.bias
# freezing model.6.m.1.cv2.conv.weight
# freezing model.6.m.1.cv2.bn.weight
# freezing model.6.m.1.cv2.bn.bias
# freezing model.6.m.2.cv1.conv.weight
# freezing model.6.m.2.cv1.bn.weight
# freezing model.6.m.2.cv1.bn.bias
# freezing model.6.m.2.cv2.conv.weight
# freezing model.6.m.2.cv2.bn.weight
# freezing model.6.m.2.cv2.bn.bias
# freezing model.6.m.3.cv1.conv.weight
# freezing model.6.m.3.cv1.bn.weight
# freezing model.6.m.3.cv1.bn.bias
# freezing model.6.m.3.cv2.conv.weight
# freezing model.6.m.3.cv2.bn.weight
# freezing model.6.m.3.cv2.bn.bias
# freezing model.6.m.4.cv1.conv.weight
# freezing model.6.m.4.cv1.bn.weight
# freezing model.6.m.4.cv1.bn.bias
# freezing model.6.m.4.cv2.conv.weight
# freezing model.6.m.4.cv2.bn.weight
# freezing model.6.m.4.cv2.bn.bias
# freezing model.6.m.5.cv1.conv.weight
# freezing model.6.m.5.cv1.bn.weight
# freezing model.6.m.5.cv1.bn.bias
# freezing model.6.m.5.cv2.conv.weight
# freezing model.6.m.5.cv2.bn.weight
# freezing model.6.m.5.cv2.bn.bias
# freezing model.7.conv.weight
# freezing model.7.bn.weight
# freezing model.7.bn.bias
# freezing model.8.cv1.conv.weight
# freezing model.8.cv1.bn.weight
# freezing model.8.cv1.bn.bias
# freezing model.8.cv2.conv.weight
# freezing model.8.cv2.bn.weight
# freezing model.8.cv2.bn.bias
# freezing model.8.cv3.conv.weight
# freezing model.8.cv3.bn.weight
# freezing model.8.cv3.bn.bias
# freezing model.8.m.0.cv1.conv.weight
# freezing model.8.m.0.cv1.bn.weight
# freezing model.8.m.0.cv1.bn.bias
# freezing model.8.m.0.cv2.conv.weight
# freezing model.8.m.0.cv2.bn.weight
# freezing model.8.m.0.cv2.bn.bias
# freezing model.8.m.1.cv1.conv.weight
# freezing model.8.m.1.cv1.bn.weight
# freezing model.8.m.1.cv1.bn.bias
# freezing model.8.m.1.cv2.conv.weight
# freezing model.8.m.1.cv2.bn.weight
# freezing model.8.m.1.cv2.bn.bias
# freezing model.9.conv.weight
# freezing model.9.bn.weight
# freezing model.9.bn.bias
# freezing model.10.cv1.conv.weight
# freezing model.10.cv1.bn.weight
# freezing model.10.cv1.bn.bias
# freezing model.10.cv2.conv.weight
# freezing model.10.cv2.bn.weight
# freezing model.10.cv2.bn.bias
# freezing model.10.cv3.conv.weight
# freezing model.10.cv3.bn.weight
# freezing model.10.cv3.bn.bias
# freezing model.10.m.0.cv1.conv.weight
# freezing model.10.m.0.cv1.bn.weight
# freezing model.10.m.0.cv1.bn.bias
# freezing model.10.m.0.cv2.conv.weight
# freezing model.10.m.0.cv2.bn.weight
# freezing model.10.m.0.cv2.bn.bias
# freezing model.10.m.1.cv1.conv.weight
# freezing model.10.m.1.cv1.bn.weight
# freezing model.10.m.1.cv1.bn.bias
# freezing model.10.m.1.cv2.conv.weight
# freezing model.10.m.1.cv2.bn.weight
# freezing model.10.m.1.cv2.bn.bias
# freezing model.11.cv1.conv.weight
# freezing model.11.cv1.bn.weight
# freezing model.11.cv1.bn.bias
# freezing model.11.cv2.conv.weight
# freezing model.11.cv2.bn.weight
# freezing model.11.cv2.bn.bias
# optimizer: SGD(lr=0.01) with parameter groups 103 weight(decay=0.0), 107 weight(decay=0.000625), 107 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /kaggle/working/yolov5/train/labels... 6784 images, 19 backgroun
# train: WARNING ⚠️ /kaggle/working/yolov5/train/images/136edit_jpg.rf.b6b1b155cd9d418d04f1df0c7a100d84.jpg: 1 duplicate labels removed
# train: New cache created: /kaggle/working/yolov5/train/labels.cache
# train: Caching images (7.8GB ram): 100%|██████████| 6784/6784 [00:11<00:00, 615.
# val: Scanning /kaggle/working/yolov5/valid/labels... 958 images, 5 backgrounds,
# val: WARNING ⚠️ /kaggle/working/yolov5/valid/images/136edit_jpg.rf.fde52510782742f9cb058cd54e355129.jpg: 1 duplicate labels removed
# val: New cache created: /kaggle/working/yolov5/valid/labels.cache
# val: Caching images (1.1GB ram): 100%|██████████| 958/958 [00:04<00:00, 215.65it
#
# AutoAnchor: 6.48 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to yolov5_train/feature_extraction/labels.jpg...
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to yolov5_train/feature_extraction
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/99        13G    0.06022     0.0268    0.07471        181        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.114      0.118     0.0846     0.0415
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/99      14.9G    0.03758    0.01904    0.06778        207        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.241      0.387      0.201      0.131
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/99      14.9G     0.0352    0.01494      0.054        193        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.367      0.592      0.447      0.278
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/99      14.9G    0.03052    0.01344    0.03726        178        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.509      0.754      0.669      0.467
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/99      14.9G    0.02733    0.01302     0.0282        226        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.772        0.8      0.827      0.627
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/99      14.9G     0.0253    0.01272    0.02326        201        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.835      0.816      0.868      0.688
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/99      14.9G    0.02383     0.0123    0.02012        189        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.892      0.845      0.892      0.684
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/99      14.9G    0.02313    0.01209    0.01825        192        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.897      0.842      0.898       0.72
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/99      14.9G    0.02245    0.01224    0.01659        193        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.886       0.88       0.92      0.749
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/99      14.9G    0.02189    0.01181     0.0155        206        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.805      0.926      0.921      0.762
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/99      14.9G    0.02133    0.01207    0.01484        209        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.871      0.941      0.941      0.772
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/99      14.9G    0.02099    0.01185    0.01344        207        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208       0.91      0.901      0.948      0.795
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/99      14.9G     0.0207    0.01177    0.01334        178        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.907      0.918      0.959      0.794
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/99      14.9G    0.02018    0.01151    0.01248        195        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.925      0.932      0.963      0.807
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/99      14.9G     0.0197    0.01145    0.01208        198        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.902      0.923      0.953      0.801
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/99      14.9G    0.01949    0.01153    0.01163        213        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.908      0.923      0.956      0.799
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/99      14.9G    0.01896    0.01111    0.01127        201        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.922      0.942      0.962      0.812
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/99      14.9G    0.01878    0.01128    0.01072        208        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.929      0.947      0.963      0.819
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/99      14.9G    0.01869    0.01117    0.01027        189        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.928      0.935      0.965      0.831
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/99      14.9G    0.01831    0.01096    0.01042        196        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.939      0.943      0.965      0.832
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       20/99      14.9G    0.01811    0.01115   0.009877        198        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.947      0.945      0.969      0.838
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       21/99      14.9G    0.01785     0.0109   0.009344        193        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.948      0.941      0.968      0.844
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       22/99      14.9G    0.01764    0.01086   0.009285        204        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208       0.94       0.95      0.967      0.844
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       23/99      14.9G    0.01737    0.01066   0.009009        183        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.952      0.943       0.97      0.845
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       24/99      14.9G    0.01727    0.01073   0.008856        195        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.939      0.939      0.966      0.853
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       25/99      14.9G     0.0169     0.0106   0.008844        212        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.942       0.95      0.969      0.853
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       26/99      14.9G    0.01703    0.01063   0.008534        205        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.952      0.948       0.97      0.864
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       27/99      14.9G    0.01679    0.01057   0.008231        187        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.934      0.948      0.971      0.861
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       28/99      14.9G    0.01648    0.01038   0.007997        206        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.953      0.949       0.97      0.861
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       29/99      14.9G     0.0162    0.01038   0.008118        183        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208       0.95       0.95      0.971      0.861
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       30/99      14.9G    0.01615     0.0105   0.007711        179        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.947      0.949      0.971      0.876
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       31/99      14.9G    0.01591    0.01031   0.007702        197        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.936      0.962      0.971       0.87
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       32/99      14.9G     0.0158    0.01029   0.007492        202        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.948      0.958      0.971      0.869
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       33/99      14.9G     0.0157    0.01013   0.007277        173        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.956       0.95      0.972      0.876
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       34/99      14.9G    0.01571     0.0101   0.006925        203        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.946      0.957      0.968      0.872
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       35/99      14.9G     0.0155     0.0102   0.006931        204        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.945      0.957      0.972      0.882
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       36/99      14.9G    0.01542    0.01003   0.006875        220        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.961      0.957      0.975      0.886
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       37/99      14.9G    0.01515   0.009981   0.006779        171        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.959      0.959      0.973      0.881
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       38/99      14.9G    0.01503    0.01001    0.00668        190        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.952       0.96      0.972      0.889
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       39/99      14.9G    0.01511    0.01005   0.006741        202        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.954      0.962      0.975      0.882
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       40/99      14.9G    0.01486   0.009833   0.006442        201        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.961      0.952      0.976      0.884
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       41/99      14.9G    0.01487    0.00983   0.006317        183        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.961      0.943      0.969      0.883
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       42/99      14.9G    0.01454   0.009737   0.006458        199        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.958      0.958       0.97      0.886
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       43/99      14.9G    0.01457   0.009947   0.005984        202        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.958      0.956      0.974      0.895
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       44/99      14.9G    0.01435   0.009806   0.006069        182        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.948      0.966      0.974      0.895
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       45/99      14.9G    0.01432    0.00985   0.005947        217        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208       0.95       0.96      0.973      0.895
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       46/99      14.9G    0.01422   0.009666   0.005714        202        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.959      0.956      0.972      0.895
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       47/99      14.9G    0.01401   0.009586   0.005633        188        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.962      0.961      0.974      0.895
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       48/99      14.9G    0.01391   0.009681    0.00566        192        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208       0.96      0.958      0.973        0.9
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       49/99      14.9G    0.01388   0.009471   0.005589        190        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.955       0.96      0.975      0.901
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       50/99      14.9G    0.01365   0.009541   0.005466        233        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.957      0.961      0.974        0.9
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       51/99      14.9G    0.01364   0.009354   0.005338        209        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.951      0.966      0.975      0.903
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       52/99      14.9G    0.01352    0.00936    0.00541        195        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.965      0.956      0.975      0.904
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       53/99      14.9G    0.01354   0.009508   0.005235        179        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.953      0.971      0.976      0.906
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       54/99      14.9G    0.01329   0.009352   0.005149        189        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.957      0.967      0.977      0.904
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       55/99      14.9G    0.01317    0.00926   0.005093        208        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.967      0.963      0.977      0.905
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       56/99      14.9G    0.01318   0.009236    0.00508        195        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208       0.97       0.95      0.975      0.902
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       57/99      14.9G    0.01298    0.00921   0.004832        180        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.961       0.96      0.975      0.901
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       58/99      14.9G    0.01282   0.009159   0.004852        181        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208       0.96      0.963      0.975      0.906
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       59/99      14.9G    0.01281   0.009244   0.004923        191        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.971      0.957      0.977      0.908
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       60/99      14.9G    0.01266   0.009095   0.004834        181        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.952      0.965      0.973      0.907
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       61/99      14.9G    0.01275   0.009184   0.004823        194        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.961      0.966      0.976       0.91
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       62/99      14.9G    0.01248   0.009045   0.004754        193        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.965      0.963      0.976      0.907
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       63/99      14.9G    0.01244   0.009028   0.004714        179        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.965      0.965      0.977      0.911
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       64/99      14.9G    0.01231    0.00892   0.004683        204        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.967      0.957      0.977      0.914
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       65/99      14.9G    0.01241    0.00898   0.004463        215        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208       0.97      0.963      0.977      0.911
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       66/99      14.9G    0.01219   0.009003   0.004226        217        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.972      0.959      0.978      0.912
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       67/99      14.9G    0.01214   0.009096   0.004301        209        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.969       0.96      0.977      0.914
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       68/99      14.9G     0.0121   0.008948   0.004297        184        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.962      0.968      0.978      0.914
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       69/99      14.9G    0.01194   0.008757   0.004321        203        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208       0.96      0.968      0.978      0.918
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       70/99      14.9G    0.01182   0.008652   0.004081        202        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.968      0.963      0.978      0.915
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       71/99      14.9G    0.01159   0.008696   0.004067        212        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.967      0.961      0.976      0.915
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       72/99      14.9G    0.01163   0.008786   0.003937        165        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208       0.97      0.965      0.978      0.917
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       73/99      14.9G    0.01134   0.008573   0.004135        194        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.969      0.962      0.978      0.916
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       74/99      14.9G    0.01141   0.008733   0.003845        197        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.971      0.966      0.978      0.918
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       75/99      14.9G    0.01141   0.008747   0.003879        211        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.972      0.963      0.976      0.917
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       76/99      14.9G    0.01132   0.008577   0.003837        188        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.971      0.961      0.976      0.918
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       77/99      14.9G    0.01107     0.0085   0.003573        183        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.972      0.956      0.977       0.92
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       78/99      14.9G    0.01105   0.008548   0.003572        229        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.968      0.961      0.978      0.922
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       79/99      14.9G    0.01068    0.00849   0.003654        196        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.966      0.964      0.977       0.92
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       80/99      14.9G    0.01068    0.00847    0.00358        226        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.965      0.961      0.977      0.919
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       81/99      14.9G    0.01069   0.008508   0.003532        189        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.968      0.958      0.977       0.92
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       82/99      14.9G    0.01063   0.008445   0.003538        207        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.974      0.957      0.979      0.923
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       83/99      14.9G    0.01044   0.008297   0.003326        220        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.974      0.961      0.979      0.925
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       84/99      14.9G    0.01033   0.008225   0.003259        200        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.971      0.963      0.979      0.922
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       85/99      14.9G    0.01018   0.008323   0.003242        181        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.973      0.957      0.979      0.923
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       86/99      14.9G    0.01015   0.008272   0.002996        181        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.972      0.955      0.978      0.922
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       87/99      14.9G    0.01007   0.008136   0.003003        196        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.973      0.963      0.979      0.925
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       88/99      14.9G   0.009922   0.008158   0.003268        165        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.971      0.961       0.98      0.925
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       89/99      14.9G   0.009867   0.008132   0.002966        191        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.972      0.962      0.979      0.925
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       90/99      14.9G    0.00975   0.008056   0.002923        190        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.973      0.961      0.978      0.924
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       91/99      14.9G   0.009626   0.008022   0.002994        175        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.973      0.959      0.978      0.926
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       92/99      14.9G   0.009623   0.008033   0.002643        197        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.973      0.963      0.979      0.926
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       93/99      14.9G   0.009421   0.007917   0.002813        213        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208       0.97      0.965      0.979      0.927
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       94/99      14.9G   0.009358    0.00801   0.002717        193        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.973      0.965       0.98      0.927
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       95/99      14.9G   0.009231   0.008003   0.002702        189        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.966      0.968       0.98      0.928
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       96/99      14.9G    0.00916   0.007974   0.002574        189        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.969      0.964       0.98      0.927
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       97/99      14.9G   0.009042   0.007893   0.002502        210        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.975      0.961      0.979      0.927
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       98/99      14.9G   0.008938   0.007719   0.002673        208        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.974      0.961      0.979      0.928
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       99/99      14.9G   0.008867   0.007846   0.002485        184        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.976      0.961      0.979      0.927
#
# 100 epochs completed in 3.196 hours.
# Optimizer stripped from yolov5_train/feature_extraction/weights/last.pt, 71.4MB
# Optimizer stripped from yolov5_train/feature_extraction/weights/best.pt, 71.4MB
#
# Validating yolov5_train/feature_extraction/weights/best.pt...
# Fusing layers...
# Model summary: 276 layers, 35358588 parameters, 0 gradients, 49.1 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all        958       1208      0.966      0.969       0.98      0.928
#      chilli antracnose        958        165      0.923      0.958      0.964      0.818
# chilli bacterial leaf spot        958         78      0.974      0.987      0.993      0.964
# chilli mosaic leaf virus        958         48      0.952      0.979      0.972      0.965
# eggplant cercospora leaf spot        958         57      0.976          1      0.993      0.945
# eggplant colorado potato beetle        958         39          1      0.995      0.995      0.954
#     eggplant fruit rot        958         10      0.961          1      0.995      0.945
#      eggplant fuit rot        958         49       0.97          1      0.993      0.943
# eggplant healthy fruit        958         65      0.969      0.965      0.992      0.962
#  eggplant healthy leaf        958         50      0.988          1      0.995       0.95
#    healthy chilli leaf        958         78      0.993          1      0.995      0.927
#         healthy chilli        958         69      0.954      0.912      0.939      0.827
# potato alternaria solani leaf        958         50      0.973          1      0.995      0.989
# potato common scab fruit        958         51      0.991          1      0.995      0.995
#   potato healthy fruit        958        106      0.894      0.877       0.94      0.853
#    potato healthy leaf        958         59      0.946      0.983       0.99      0.977
# potato pythopthora infestans leaf        958         42      0.977      0.993      0.995      0.975
#      tomato antracnose        958         43      0.989          1      0.995      0.973
#  tomato bacterial spot        958         42      0.937          1      0.993      0.983
#         tomato healthy        958         54      0.959      0.759      0.884      0.659
# tomato late blight leaf        958         53      0.986      0.962      0.994      0.952
# Results saved to yolov5_train/feature_extraction

# %% [markdown]
# # Validation

# %%
WEIGHTS_BEST = f"{PROJECT_NAME}/feature_extraction/weights/best.pt"
! python val.py --weights $WEIGHTS_BEST --batch $VAL_BATCH --data 'data.yaml' --task test --project $PROJECT_NAME --name 'validation_on_test_data' --augment
# Out:
# val: data=data.yaml, weights=['yolov5_train/feature_extraction/weights/best.pt'], batch_size=64, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=True, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov5_train, name=validation_on_test_data, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-295-gac6c4383 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
#
# Fusing layers...
# Model summary: 276 layers, 35358588 parameters, 0 gradients, 49.1 GFLOPs
# test: Scanning /kaggle/working/yolov5/test/labels... 240 images, 0 backgrounds,
# test: New cache created: /kaggle/working/yolov5/test/labels.cache
#                  Class     Images  Instances          P          R      mAP50
#                    all        240        321      0.924      0.959      0.967      0.909
#      chilli antracnose        240         29      0.917      0.966      0.968      0.878
# chilli bacterial leaf spot        240         19      0.899          1      0.995       0.91
# chilli mosaic leaf virus        240          8      0.928          1      0.995       0.96
# eggplant cercospora leaf spot        240          9      0.943          1      0.995      0.918
# eggplant colorado potato beetle        240          6        0.9          1      0.995      0.934
#      eggplant fuit rot        240         12      0.838          1      0.995       0.96
# eggplant healthy fruit        240         19          1      0.987      0.995       0.97
#  eggplant healthy leaf        240         35          1      0.685       0.78      0.564
#    healthy chilli leaf        240         20      0.974          1      0.995      0.963
#         healthy chilli        240         21      0.974      0.857      0.931      0.896
# potato alternaria solani leaf        240         16      0.967          1      0.995      0.989
# potato common scab fruit        240         15      0.965          1      0.995      0.995
#   potato healthy fruit        240         21      0.766      0.938      0.889      0.824
#    potato healthy leaf        240         19      0.933      0.947      0.978      0.954
# potato pythopthora infestans leaf        240         15      0.965          1      0.995      0.995
#      tomato antracnose        240         17      0.968          1      0.995      0.983
#  tomato bacterial spot        240         10      0.875          1      0.995      0.995
#         tomato healthy        240         20      0.929       0.85        0.9      0.653
# tomato late blight leaf        240         10       0.82          1      0.995      0.924
# Speed: 0.3ms pre-process, 23.2ms inference, 2.5ms NMS per image at shape (64, 3, 640, 640)
# Results saved to yolov5_train/validation_on_test_data

# %% [markdown]
# # Test detection

# %%
! python detect.py --weights $WEIGHTS_BEST --conf 0.6 --source 'test/images' --project $PROJECT_NAME --name 'detect_test' --augment --line=3
# Out:
# detect: weights=['yolov5_train/feature_extraction/weights/best.pt'], source=test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=True, visualize=False, update=False, project=yolov5_train, name=detect_test, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-295-gac6c4383 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
#
# Fusing layers...
# Model summary: 276 layers, 35358588 parameters, 0 gradients, 49.1 GFLOPs
# image 1/240 /kaggle/working/yolov5/test/images/-117-edit_jpg.rf.8a4db31a2e26142a19d8939599271fb7.jpg: 640x640 1 eggplant colorado potato beetle, 152.7ms
# image 2/240 /kaggle/working/yolov5/test/images/-131-edit_jpg.rf.cce2afe11f4db1ff4ab768767f29bdee.jpg: 640x640 1 eggplant colorado potato beetle, 41.4ms
# image 3/240 /kaggle/working/yolov5/test/images/-133-_jpg.rf.7c6bdad97ad2a2b084e9591d6f61485a.jpg: 640x640 1 eggplant colorado potato beetle, 41.4ms
# image 4/240 /kaggle/working/yolov5/test/images/-184-_jpg.rf.306765cc14ab89b017598114389363b3.jpg: 640x640 1 eggplant cercospora leaf spot, 37.8ms
# image 5/240 /kaggle/working/yolov5/test/images/-194-_jpg.rf.42a222797bc5eae8704e319a2be0b2be.jpg: 640x640 1 eggplant cercospora leaf spot, 37.8ms
# image 6/240 /kaggle/working/yolov5/test/images/-205-edit_jpg.rf.4775d0ab521ea4efaa9b36d9eebcdbe7.jpg: 640x640 1 eggplant colorado potato beetle, 37.7ms
# image 7/240 /kaggle/working/yolov5/test/images/-207-edit_jpg.rf.d5eaf9346cfb0c328e3c4267a5b8e5cb.jpg: 640x640 1 eggplant colorado potato beetle, 37.8ms
# image 8/240 /kaggle/working/yolov5/test/images/-216-_jpg.rf.bc91d7cb014b97fc5a8019adb19c1a73.jpg: 640x640 1 eggplant colorado potato beetle, 37.5ms
# image 9/240 /kaggle/working/yolov5/test/images/0082_jpg.rf.fdd73be08d7bcd38a373ca488d346b5d.jpg: 640x640 4 potato healthy fruits, 37.7ms
# image 10/240 /kaggle/working/yolov5/test/images/0103_jpg.rf.b1f7526a6e8c9d624b330e0e7d5386d8.jpg: 640x640 1 potato healthy fruit, 37.7ms
# image 11/240 /kaggle/working/yolov5/test/images/0173_jpg.rf.5a519a7621649a9bcf639bf8ac07545a.jpg: 640x640 1 potato healthy fruit, 37.6ms
# image 12/240 /kaggle/working/yolov5/test/images/0198_jpg.rf.25a9751968812b563dcc5d85e368820c.jpg: 640x640 3 potato healthy fruits, 37.6ms
# image 13/240 /kaggle/working/yolov5/test/images/0217_jpg.rf.f177b7b45683f820cfcf690533a2d70c.jpg: 640x640 3 potato healthy fruits, 37.6ms
# image 14/240 /kaggle/working/yolov5/test/images/0219_jpg.rf.bdb554ebb10455ed87a057373be16338.jpg: 640x640 1 potato healthy fruit, 37.7ms
# image 15/240 /kaggle/working/yolov5/test/images/0227_jpg.rf.339cd1324e3e0947d001f3a5254dd920.jpg: 640x640 1 potato healthy fruit, 37.7ms
# image 16/240 /kaggle/working/yolov5/test/images/0230_jpg.rf.beec5baa0925f78b28f3db800daacd27.jpg: 640x640 4 potato healthy fruits, 37.4ms
# image 17/240 /kaggle/working/yolov5/test/images/0261_jpg.rf.6cfc1b8716e0a1956bfcf374d2921162.jpg: 640x640 6 potato healthy fruits, 37.5ms
# image 18/240 /kaggle/working/yolov5/test/images/0296_jpg.rf.d083810761ea911f5a6e413063c9e1df.jpg: 640x640 1 tomato healthy, 37.7ms
# image 19/240 /kaggle/working/yolov5/test/images/0350_jpg.rf.ee54d20c78ad22269171e669f9c99646.jpg: 640x640 (no detections), 37.2ms
# image 20/240 /kaggle/working/yolov5/test/images/0364_jpg.rf.52a436c01b9853f4047a9acbff9dc171.jpg: 640x640 1 tomato healthy, 37.7ms
# image 21/240 /kaggle/working/yolov5/test/images/0373_jpg.rf.6241c1b26f6d5e0b76b31db28f2960dd.jpg: 640x640 2 tomato healthys, 37.7ms
# image 22/240 /kaggle/working/yolov5/test/images/0376_jpg.rf.0c689a7cda54e7f26751b2173fc5a1e4.jpg: 640x640 2 tomato healthys, 37.7ms
# image 23/240 /kaggle/working/yolov5/test/images/0380_jpg.rf.84f587fddd01f17ab3a616d20e129b03.jpg: 640x640 2 tomato healthys, 37.7ms
# image 24/240 /kaggle/working/yolov5/test/images/0386_jpg.rf.34bc55354417830d32a2b302c0f6111b.jpg: 640x640 4 tomato healthys, 37.7ms
# image 25/240 /kaggle/working/yolov5/test/images/0396_jpg.rf.7ba6ebb79cd2dd8a233fe1faf7368e8c.jpg: 640x640 2 tomato healthys, 37.7ms
# image 26/240 /kaggle/working/yolov5/test/images/0398_jpg.rf.f7cc3fa39644f382fa134ac75660e34c.jpg: 640x640 1 tomato healthy, 37.7ms
# image 27/240 /kaggle/working/yolov5/test/images/08615b7d-eca7-487e-a9ea-07842ecf81e8___RS_Erly-B-7543_JPG.rf.48e1c99c99432fe2d1750b0fe89d7b8a.jpg: 640x640 1 tomato late blight leaf, 37.7ms
# image 28/240 /kaggle/working/yolov5/test/images/086880d1-73c4-40d3-99ea-d446c2299692___GCREC_Bact-Sp-3333_JPG.rf.3336e61ac45ac1b3fce0d26ae4bf6a5a.jpg: 640x640 1 tomato bacterial spot, 37.7ms
# image 29/240 /kaggle/working/yolov5/test/images/098-removebg-preview-3-Copy-1-_jpg.rf.3b948e29675d02af9166426e97dcea40.jpg: 640x640 1 potato common scab fruit, 37.7ms
# image 30/240 /kaggle/working/yolov5/test/images/105edit_jpg.rf.75ebc067e3d680a576c5b2077f27363a.jpg: 640x640 1 chilli mosaic leaf virus, 37.6ms
# image 31/240 /kaggle/working/yolov5/test/images/106_jpg.rf.1a5641df167f035ce09b3fe59c065d41.jpg: 640x640 1 healthy chilli, 37.7ms
# image 32/240 /kaggle/working/yolov5/test/images/106edit_jpg.rf.4e5271b44243251d132d33de89fb5bb2.jpg: 640x640 1 healthy chilli, 37.8ms
# image 33/240 /kaggle/working/yolov5/test/images/108edit_jpg.rf.d47b3296db415e3c22759141552d3cd0.jpg: 640x640 1 healthy chilli, 37.7ms
# image 34/240 /kaggle/working/yolov5/test/images/109edit_jpg.rf.025648ac29d52f010172f319ccdedcf8.jpg: 640x640 1 chilli mosaic leaf virus, 37.6ms
# image 35/240 /kaggle/working/yolov5/test/images/110818-002-Potato-scab-removebg-previewedit_jpg.rf.f7b6964cc5f5819e57ec55259934b280.jpg: 640x640 1 potato common scab fruit, 37.5ms
# image 36/240 /kaggle/working/yolov5/test/images/1138589233-01-_SCLZZZZZZZ_SX500_-removebg-preview-2-_jpg.rf.ff691d8dc598020a6c592aa4e6b81091.jpg: 640x640 1 chilli antracnose, 37.7ms
# image 37/240 /kaggle/working/yolov5/test/images/1138589233-01-_SCLZZZZZZZ_SX500_-removebg-preview-3-Copyedit_jpg.rf.f48394cba79ad40b899c68ce87a12ec6.jpg: 640x640 1 chilli antracnose, 37.6ms
# image 38/240 /kaggle/working/yolov5/test/images/114edit_jpg.rf.f13ee38faa2c309b0d98d8a113c6662f.jpg: 640x640 1 healthy chilli, 37.7ms
# image 39/240 /kaggle/working/yolov5/test/images/116edit_jpg.rf.abe83340a484a8e444540b917992b577.jpg: 640x640 1 healthy chilli, 37.7ms
# image 40/240 /kaggle/working/yolov5/test/images/11_jpg.rf.f081c9e3baf17214ef15ebc2cf1e0f64.jpg: 640x640 1 healthy chilli, 37.6ms
# image 41/240 /kaggle/working/yolov5/test/images/120_jpg.rf.f56dc776be6c6f02db49456c519ec55a.jpg: 640x640 1 chilli bacterial leaf spot, 37.7ms
# image 42/240 /kaggle/working/yolov5/test/images/123edit_jpg.rf.2fb6cdd82b44b0046a2705a88268e353.jpg: 640x640 1 chilli mosaic leaf virus, 37.7ms
# image 43/240 /kaggle/working/yolov5/test/images/134_jpg.rf.7e3cc0961bcbcb4fd2f8bd9ffb19ed57.jpg: 640x640 1 chilli mosaic leaf virus, 37.6ms
# image 44/240 /kaggle/working/yolov5/test/images/15174816930_eec94dbedc_k-2-_jpg.rf.ded8d0b2ce6bcfb515eef4fa1637d0da.jpg: 640x640 1 eggplant cercospora leaf spot, 37.7ms
# image 45/240 /kaggle/working/yolov5/test/images/1573333-PPT-Copy-6-_jpg.rf.f1a6fceb2cc5e6e09aecc6b7c70e671c.jpg: 640x640 1 potato common scab fruit, 37.7ms
# image 46/240 /kaggle/working/yolov5/test/images/1578008-PPT-1-_jpg.rf.4da513944aaaaf75362bc5234e3323ce.jpg: 640x640 1 potato common scab fruit, 37.7ms
# image 47/240 /kaggle/working/yolov5/test/images/1578011-PPT-Copy-2-1-_jpg.rf.026111a88059d8941d44f60a3e0b655f.jpg: 640x640 1 potato common scab fruit, 37.6ms
# image 48/240 /kaggle/working/yolov5/test/images/1578011-PPT-Copy-2-_jpg.rf.21f62032d53232843981f35ce3de7f63.jpg: 640x640 1 potato common scab fruit, 37.6ms
# image 49/240 /kaggle/working/yolov5/test/images/1578011-PPT-Copy-3-_jpg.rf.981bca83014b6f85f8407f8b61d4519c.jpg: 640x640 1 potato common scab fruit, 37.6ms
# image 50/240 /kaggle/working/yolov5/test/images/15802673221_37ede98d37_z-removebg-preview_jpg.rf.7554b025f658ab77aa08a1c246272ad6.jpg: 640x640 1 eggplant cercospora leaf spot, 37.6ms
# image 51/240 /kaggle/working/yolov5/test/images/15_jpg.rf.776ac3f92709c6a66c6edcec2603e61c.jpg: 640x640 1 healthy chilli, 37.7ms
# image 52/240 /kaggle/working/yolov5/test/images/160_jpg.rf.c9a9e98fc436934d0fb2ff51792d78a8.jpg: 640x640 1 chilli bacterial leaf spot, 37.6ms
# image 53/240 /kaggle/working/yolov5/test/images/182_jpg.rf.cb5fde13eb024980e28497ec6d101924.jpg: 640x640 1 chilli bacterial leaf spot, 37.7ms
# image 54/240 /kaggle/working/yolov5/test/images/188_jpg.rf.a961cc131d7a0c04bcb5baadeac7f7c9.jpg: 640x640 1 chilli bacterial leaf spot, 37.7ms
# image 55/240 /kaggle/working/yolov5/test/images/18edit_jpg.rf.6ea14cb31a8531c00c90c14cec70d4b0.jpg: 640x640 1 healthy chilli, 37.7ms
# image 56/240 /kaggle/working/yolov5/test/images/199_jpg.rf.2fa990405011f37535992d3a32917a2c.jpg: 640x640 1 chilli bacterial leaf spot, 37.7ms
# image 57/240 /kaggle/working/yolov5/test/images/1scab-removebg-preview-1-_jpg.rf.62a79df9349351798cb1c08120c2d7ee.jpg: 640x640 1 potato common scab fruit, 37.7ms
# image 58/240 /kaggle/working/yolov5/test/images/1scab-removebg-preview-12-Copy_jpg.rf.9c4176d14a776dafaf8eb64190b1f0d5.jpg: 640x640 1 potato common scab fruit, 37.5ms
# image 59/240 /kaggle/working/yolov5/test/images/1scab-removebg-preview-7-edit_jpg.rf.1112b25ae2d2ac4de7ef7ce37ad2ff61.jpg: 640x640 1 potato common scab fruit, 37.8ms
# image 60/240 /kaggle/working/yolov5/test/images/1scab-removebg-preview-8-_jpg.rf.9f6059f2305b90a8679ee417bffe0a74.jpg: 640x640 1 potato common scab fruit, 37.6ms
# image 61/240 /kaggle/working/yolov5/test/images/2-skinning-cmyk-opt-removebg-preview-2-_jpg.rf.a272b101d003b0ea81abd7c4c7d74f14.jpg: 640x640 1 potato common scab fruit, 37.7ms
# image 62/240 /kaggle/working/yolov5/test/images/200_jpg.rf.30db71393ffd8aa40f594b89933c5f90.jpg: 640x640 3 chilli bacterial leaf spots, 37.7ms
# image 63/240 /kaggle/working/yolov5/test/images/20160821121754_scaled-5-edit_jpg.rf.ffb11ce14c8be17f024d45738ab05c78.jpg: 640x640 1 eggplant healthy leaf, 37.7ms
# image 64/240 /kaggle/working/yolov5/test/images/20160821121754_scaledd-3-_jpg.rf.add7fbccaf8e749ed5484e3e1ad08e47.jpg: 640x640 1 eggplant healthy leaf, 37.7ms
# image 65/240 /kaggle/working/yolov5/test/images/20160821121754_scaledd-removebg-preview-5-edit_jpg.rf.ad53560373bd0719336dc479d7375103.jpg: 640x640 1 eggplant healthy leaf, 37.6ms
# image 66/240 /kaggle/working/yolov5/test/images/211_jpg.rf.ad35780ca9d6d19b3c875f90c6feaaa0.jpg: 640x640 1 chilli bacterial leaf spot, 37.6ms
# image 67/240 /kaggle/working/yolov5/test/images/213539dc-f50d-4f98-a380-4fcfc575d208___UF-GRC_BS_Lab-Leaf-9122_JPG.rf.e9bf1e3ae3e60f58adb98c2dfb7b003d.jpg: 640x640 1 tomato bacterial spot, 37.6ms
# image 68/240 /kaggle/working/yolov5/test/images/21_jpg.rf.00edb6bd51b53f64dd43f667c31091ef.jpg: 640x640 1 chilli mosaic leaf virus, 37.6ms
# image 69/240 /kaggle/working/yolov5/test/images/220px-Cercospora_Melongenae-1-_jpg.rf.457954be72bad6fced459a0fb4955411.jpg: 640x640 1 eggplant cercospora leaf spot, 37.7ms
# image 70/240 /kaggle/working/yolov5/test/images/263_jpg.rf.4376f8399594e486b323fb658989afec.jpg: 640x640 1 chilli bacterial leaf spot, 37.7ms
# image 71/240 /kaggle/working/yolov5/test/images/272_jpg.rf.54b974349ed658efc697e1d4866e499d.jpg: 640x640 1 chilli bacterial leaf spot, 37.7ms
# image 72/240 /kaggle/working/yolov5/test/images/2763c9bc-ecc6-4f1a-86a7-ef8ffa370420___RS_Erly-B-8422_JPG.rf.6fb4ab8356c15b0f50c4be0a4aa70488.jpg: 640x640 1 tomato late blight leaf, 37.8ms
# image 73/240 /kaggle/working/yolov5/test/images/27a_jpg.rf.3379737a7c7aafee7bc2518b6c921991.jpg: 640x640 1 tomato antracnose, 37.7ms
# image 74/240 /kaggle/working/yolov5/test/images/27edit_jpg.rf.b629d30434a6a002f8c914accac85cbe.jpg: 640x640 1 tomato antracnose, 37.3ms
# image 75/240 /kaggle/working/yolov5/test/images/288896d1-7094-4250-9fd6-00589c41b42a___UF-GRC_BS_Lab-Leaf-0264_JPG.rf.c1ca1b622ad5b251a2da6eb50860b87c.jpg: 640x640 1 tomato bacterial spot, 37.7ms
# image 76/240 /kaggle/working/yolov5/test/images/295_jpg.rf.96dbbe73e3acd8e947eb4d00dd9993ce.jpg: 640x640 1 chilli bacterial leaf spot, 37.7ms
# image 77/240 /kaggle/working/yolov5/test/images/29d_jpg.rf.8675b62736d8f5646ebd4b913c3d1332.jpg: 640x640 1 tomato antracnose, 37.7ms
# image 78/240 /kaggle/working/yolov5/test/images/30d_jpg.rf.bea68ca746d98ea265830c6a1c923d88.jpg: 640x640 1 tomato antracnose, 37.7ms
# image 79/240 /kaggle/working/yolov5/test/images/314_jpg.rf.c4afee93c7aa5b79236656c3b52cdac7.jpg: 640x640 1 chilli bacterial leaf spot, 37.7ms
# image 80/240 /kaggle/working/yolov5/test/images/31d_jpg.rf.770360b3d54c2af48a760a0a7baa042a.jpg: 640x640 1 tomato antracnose, 37.7ms
# image 81/240 /kaggle/working/yolov5/test/images/321_jpg.rf.e4b33507149dba162861eebf58564e4a.jpg: 640x640 1 chilli bacterial leaf spot, 37.6ms
# image 82/240 /kaggle/working/yolov5/test/images/32ceditsecond_jpg.rf.13464dfdd52f914d4821fe9b7abd5cab.jpg: 640x640 1 tomato antracnose, 37.3ms
# image 83/240 /kaggle/working/yolov5/test/images/34editsecond_jpg.rf.ea07f372211fc5f176badaacd06ca5d3.jpg: 640x640 1 tomato antracnose, 37.5ms
# image 84/240 /kaggle/working/yolov5/test/images/3537d467-9926-49dc-8d11-74a76b196354___RS_Erly-B-7665_JPG.rf.07f8fd8171dccd111fce3e8f69e45464.jpg: 640x640 1 tomato late blight leaf, 37.6ms
# image 85/240 /kaggle/working/yolov5/test/images/3754ec0a-13b7-40c5-9839-b7499b6c365b___RS_Erly-B-7449_JPG.rf.7a90eefb9addc73375cef1913d1c8c22.jpg: 640x640 1 tomato late blight leaf, 37.5ms
# image 86/240 /kaggle/working/yolov5/test/images/37a_jpg.rf.83d65e7845898902fe9d8a2ddd01aa81.jpg: 640x640 1 tomato antracnose, 37.6ms
# image 87/240 /kaggle/working/yolov5/test/images/37b_jpg.rf.ef9d1b1cf6021ac1aa5b6c762f6d09c2.jpg: 640x640 1 tomato antracnose, 37.7ms
# image 88/240 /kaggle/working/yolov5/test/images/37beditsecond_jpg.rf.dc480c29d643727f9d5b54c18bf181bd.jpg: 640x640 1 tomato antracnose, 37.6ms
# image 89/240 /kaggle/working/yolov5/test/images/38b_jpg.rf.9332182df33709b93c9565887fbeadb6.jpg: 640x640 1 tomato antracnose, 37.6ms
# image 90/240 /kaggle/working/yolov5/test/images/38d_jpg.rf.2208d6e17d85c33bb39aefc7ebdebe4a.jpg: 640x640 1 tomato antracnose, 37.7ms
# image 91/240 /kaggle/working/yolov5/test/images/38deditsecond_jpg.rf.069246d7068e9292374c8cca6ca63a48.jpg: 640x640 1 tomato antracnose, 37.7ms
# image 92/240 /kaggle/working/yolov5/test/images/38editsecond_jpg.rf.52a3e55bd8257ab61020e6090c049c1c.jpg: 640x640 1 tomato antracnose, 37.7ms
# image 93/240 /kaggle/working/yolov5/test/images/39_jpg.rf.818ba5762648328373832bb59286e544.jpg: 640x640 1 chilli bacterial leaf spot, 37.6ms
# image 94/240 /kaggle/working/yolov5/test/images/39b_jpg.rf.57c953bfdd65a6bc7910931f9c53883b.jpg: 640x640 1 tomato antracnose, 37.7ms
# image 95/240 /kaggle/working/yolov5/test/images/40688c11-791b-465a-9476-a5069e24a56f___GCREC_Bact-Sp-3064_JPG.rf.8595390bef19f3264a20a97946cb5d7a.jpg: 640x640 1 tomato bacterial spot, 37.7ms
# image 96/240 /kaggle/working/yolov5/test/images/40ceditsecond_jpg.rf.a86beb38f4f6e3e1ad2dc9ef7ce2297d.jpg: 640x640 1 tomato antracnose, 37.8ms
# image 97/240 /kaggle/working/yolov5/test/images/42a_jpg.rf.37a5cee34a54eb6d208f475ddc525eb0.jpg: 640x640 1 tomato antracnose, 37.7ms
# image 98/240 /kaggle/working/yolov5/test/images/48edit_jpg.rf.bda0bca87e022cab8b6daa0133438575.jpg: 640x640 1 healthy chilli, 37.7ms
# image 99/240 /kaggle/working/yolov5/test/images/5402975-PPT-removebg-preview-3-Copy_jpg.rf.24df463fd2e01c66039c495e46e0f157.jpg: 640x640 1 potato common scab fruit, 37.6ms
# image 100/240 /kaggle/working/yolov5/test/images/5402975-PPT-removebg-preview-3-Copyedit_jpg.rf.a3ab46853a6c680887274134466dc2cc.jpg: 640x640 1 potato common scab fruit, 37.3ms
# image 101/240 /kaggle/working/yolov5/test/images/5402975-PPT-removebg-preview-3-_jpg.rf.bf815728c065503a30a819cd333f18d5.jpg: 640x640 1 potato common scab fruit, 37.6ms
# image 102/240 /kaggle/working/yolov5/test/images/55_jpg.rf.eaa111ae08a2649f7a6e06d74436ad38.jpg: 640x640 2 chilli bacterial leaf spots, 37.6ms
# image 103/240 /kaggle/working/yolov5/test/images/59_jpg.rf.131bd619a3b25fa00797fc60d21d7706.jpg: 640x640 1 chilli bacterial leaf spot, 37.7ms
# image 104/240 /kaggle/working/yolov5/test/images/63edit_jpg.rf.898d8e6ae8e2d103d94fc6f7e13bb9e1.jpg: 640x640 1 healthy chilli, 37.6ms
# image 105/240 /kaggle/working/yolov5/test/images/662555e4-c996-4945-8294-6e9dab37a80a___GCREC_Bact-Sp-5772_JPG.rf.68b8fc80102cdf70d5659761c982731d.jpg: 640x640 1 tomato bacterial spot, 37.7ms
# image 106/240 /kaggle/working/yolov5/test/images/66edit_jpg.rf.96818feef18810769302b5c084bf11e0.jpg: 640x640 2 healthy chillis, 37.7ms
# image 107/240 /kaggle/working/yolov5/test/images/680b86dc-14e0-4668-95c8-776193015146___RS_Erly-B-7854_JPG.rf.cd783faa0c95333c67e44643725ae346.jpg: 640x640 1 tomato late blight leaf, 37.6ms
# image 108/240 /kaggle/working/yolov5/test/images/68f375b0e321d998f7c1234397d37ee8-5-editsecond_jpg.rf.ff502b3c6f9f14a53e6bedd88882191c.jpg: 640x640 1 eggplant healthy leaf, 37.7ms
# image 109/240 /kaggle/working/yolov5/test/images/71206367-de88-4a81-a1e8-c11b27c4e8de___UF-GRC_BS_Lab-Leaf-9272_JPG.rf.21d29c10f89117a99131314fcb0def52.jpg: 640x640 1 tomato bacterial spot, 37.7ms
# image 110/240 /kaggle/working/yolov5/test/images/72_jpg.rf.b599f6c67a9990fd87211448a5cb534e.jpg: 640x640 1 chilli mosaic leaf virus, 37.5ms
# image 111/240 /kaggle/working/yolov5/test/images/72edit_jpg.rf.4339187cf72dfdb3e8b2c6ee8400986b.jpg: 640x640 1 chilli mosaic leaf virus, 37.7ms
# image 112/240 /kaggle/working/yolov5/test/images/75edit_jpg.rf.296c65240cfc4b315800a519c2b3c4cc.jpg: 640x640 1 chilli mosaic leaf virus, 37.7ms
# image 113/240 /kaggle/working/yolov5/test/images/82_jpg.rf.faa5c76b035e1dfe4fee43587a1716ea.jpg: 640x640 1 healthy chilli, 37.6ms
# image 114/240 /kaggle/working/yolov5/test/images/83_jpg.rf.70425f8868bbe3e46b6ba89c1081aca0.jpg: 640x640 1 healthy chilli, 37.7ms
# image 115/240 /kaggle/working/yolov5/test/images/86_jpg.rf.5d201772b0490eaf137306aeb81b2e69.jpg: 640x640 1 healthy chilli, 37.6ms
# image 116/240 /kaggle/working/yolov5/test/images/88edit_jpg.rf.253a8604a9857a3df83825c82ee5af49.jpg: 640x640 1 healthy chilli, 37.4ms
# image 117/240 /kaggle/working/yolov5/test/images/8bfd8383b89d0b64f0499d47ec9274e2_jpg.rf.307a6752f238817cb65dc340f791e502.jpg: 640x640 4 eggplant healthy fruits, 37.6ms
# image 118/240 /kaggle/working/yolov5/test/images/91b84b7f-2132-4d72-897b-95c763ce5397___JR_B-Spot-9067_jpg.rf.2472c972f393ac8f5ad7a449f752da75.jpg: 640x640 1 chilli bacterial leaf spot, 1 tomato late blight leaf, 37.6ms
# image 119/240 /kaggle/working/yolov5/test/images/95edit_jpg.rf.0344e9a7264a62f9960fd5c5ea1f71b5.jpg: 640x640 1 healthy chilli, 37.7ms
# image 120/240 /kaggle/working/yolov5/test/images/9744fa97-16b3-4a16-afc0-c86ac0397759___RS_Erly-B-6411_JPG.rf.c983a0aa90edf4e00b3a45bafa8433cd.jpg: 640x640 1 tomato late blight leaf, 37.7ms
# image 121/240 /kaggle/working/yolov5/test/images/99edit_jpg.rf.8cbd1355dd6bf07d1ed03c5d351e5519.jpg: 640x640 1 healthy chilli, 37.5ms
# image 122/240 /kaggle/working/yolov5/test/images/Capture-removebg-preview-3-_jpg.rf.c6d264d482281972079a87b54522cf0c.jpg: 640x640 1 eggplant cercospora leaf spot, 37.7ms
# image 123/240 /kaggle/working/yolov5/test/images/FMV_uwcUcAgDE6eedit_jpg.rf.355ef2280d7711fbf78069da6071a6d8.jpg: 640x640 7 chilli antracnoses, 37.7ms
# image 124/240 /kaggle/working/yolov5/test/images/Healthy130_JPG.rf.ce46f8dea35552488c60290fd6b494ce.jpg: 640x640 1 potato healthy leaf, 37.8ms
# image 125/240 /kaggle/working/yolov5/test/images/Healthy131edit_jpg.rf.8feefb522f4a72f7545a98c07994e3ae.jpg: 640x640 1 potato healthy leaf, 37.7ms
# image 126/240 /kaggle/working/yolov5/test/images/Healthy136_JPG.rf.6c89f48dac26fd7ef2ca3c7132ff9411.jpg: 640x640 1 potato healthy leaf, 37.7ms
# image 127/240 /kaggle/working/yolov5/test/images/Healthy139edit_jpg.rf.9f8637a3f2194209ab424841306481ed.jpg: 640x640 1 potato healthy leaf, 37.8ms
# image 128/240 /kaggle/working/yolov5/test/images/Healthy157_JPG.rf.5d6f60aaf8e850ec94e5ccf39d1658ff.jpg: 640x640 3 potato healthy leafs, 37.8ms
# image 129/240 /kaggle/working/yolov5/test/images/Healthy164_JPG.rf.3cf1f91b436edc91aa0830d6093ebc56.jpg: 640x640 2 potato healthy leafs, 37.8ms
# image 130/240 /kaggle/working/yolov5/test/images/Healthy172_JPG.rf.fa7c500065b39cda8715572c14c4c4f4.jpg: 640x640 3 potato healthy leafs, 37.7ms
# image 131/240 /kaggle/working/yolov5/test/images/Healthy173_JPG.rf.5a4e332ff7cd5bd97ac3bfadf436948a.jpg: 640x640 1 potato healthy leaf, 37.7ms
# image 132/240 /kaggle/working/yolov5/test/images/Healthy188edit_jpg.rf.af7131421b48c3ccf018191665dbaacb.jpg: 640x640 1 potato healthy leaf, 37.7ms
# image 133/240 /kaggle/working/yolov5/test/images/Healthy197_JPG.rf.c059fdf4623d32ddf1d2be10e678e636.jpg: 640x640 3 potato healthy leafs, 37.8ms
# image 134/240 /kaggle/working/yolov5/test/images/Healthy212_JPG.rf.72629fd69aec90f9e9ada3fed9516306.jpg: 640x640 3 potato healthy leafs, 37.8ms
# image 135/240 /kaggle/working/yolov5/test/images/Healthy217edit_jpg.rf.1016d45847eb299c056bb0bc2fb1878c.jpg: 640x640 2 potato healthy leafs, 37.7ms
# image 136/240 /kaggle/working/yolov5/test/images/Healthy218_JPG.rf.cb8a0f022cd99ea5d1f629825025802e.jpg: 640x640 1 potato healthy leaf, 37.6ms
# image 137/240 /kaggle/working/yolov5/test/images/Healthy220edit_jpg.rf.2fbf6be55cb6f543f22312b6e8ff5af6.jpg: 640x640 3 potato healthy leafs, 37.7ms
# image 138/240 /kaggle/working/yolov5/test/images/Healthy226_JPG.rf.044da7eeb4859d0e80f08640e306a149.jpg: 640x640 1 potato healthy leaf, 37.8ms
# image 139/240 /kaggle/working/yolov5/test/images/IMG_5659_jpg.rf.0d3bf5f28cf6446ea42eec06d5e899da.jpg: 640x640 1 healthy chilli leaf, 37.7ms
# image 140/240 /kaggle/working/yolov5/test/images/IMG_5670-2-_jpg.rf.17342181eb226844d853cde5db4edd6a.jpg: 640x640 1 healthy chilli leaf, 37.6ms
# image 141/240 /kaggle/working/yolov5/test/images/IMG_5671_jpg.rf.ba5df6b0924cd0572f7b9537ba750484.jpg: 640x640 1 healthy chilli leaf, 37.7ms
# image 142/240 /kaggle/working/yolov5/test/images/IMG_5674-3-_jpg.rf.ab3b173b49afcabe528f4b7b350f07aa.jpg: 640x640 1 healthy chilli leaf, 37.6ms
# image 143/240 /kaggle/working/yolov5/test/images/IMG_5702_jpg.rf.bc82dbf10f9c8273dba332f0bfee5f94.jpg: 640x640 1 healthy chilli leaf, 37.7ms
# image 144/240 /kaggle/working/yolov5/test/images/IMG_5715_jpg.rf.3dfa9f168ef9d13121f74b7a0965a762.jpg: 640x640 1 healthy chilli leaf, 37.1ms
# image 145/240 /kaggle/working/yolov5/test/images/IMG_5716_jpg.rf.3487567e351f96fbe1307fc3cef99236.jpg: 640x640 1 healthy chilli leaf, 37.6ms
# image 146/240 /kaggle/working/yolov5/test/images/IMG_5719_jpg.rf.9d9c405e21ad27be11b1de587d1daed6.jpg: 640x640 1 healthy chilli leaf, 37.7ms
# image 147/240 /kaggle/working/yolov5/test/images/IMG_5732_jpg.rf.a321b730c97bd890d4a4ca1a955556b9.jpg: 640x640 1 healthy chilli leaf, 48.4ms
# image 148/240 /kaggle/working/yolov5/test/images/IMG_7517_jpg.rf.0687a7ae61f0f9117cd0cf894cc4df80.jpg: 640x640 4 eggplant healthy fruits, 37.9ms
# image 149/240 /kaggle/working/yolov5/test/images/IMG_7935-removebg-preview-5-editsecond_jpg.rf.b71953c7ab8d29b313294fb0300b01c1.jpg: 640x640 1 eggplant healthy leaf, 37.6ms
# image 150/240 /kaggle/working/yolov5/test/images/IMG_8017-1-_jpg.rf.2f1effb18682d49dccbac72987d2d97f.jpg: 640x640 1 eggplant healthy leaf, 37.7ms
# image 151/240 /kaggle/working/yolov5/test/images/IMG_8019-5-editsecond_jpg.rf.44902a51c8bfec809c356551dcf63ea1.jpg: 640x640 1 eggplant healthy leaf, 37.7ms
# image 152/240 /kaggle/working/yolov5/test/images/IMG_8020-4-_jpg.rf.938fdb46b7dab4ba347d51940c967029.jpg: 640x640 1 eggplant healthy leaf, 37.8ms
# image 153/240 /kaggle/working/yolov5/test/images/IMG_8460-3-_jpg.rf.82344b1f1faa5df042a999c88657c8f3.jpg: 640x640 1 healthy chilli leaf, 37.7ms
# image 154/240 /kaggle/working/yolov5/test/images/IMG_8464_jpg.rf.2f6464135a1cfa65d11efd5aad9a4a9a.jpg: 640x640 1 healthy chilli leaf, 37.7ms
# image 155/240 /kaggle/working/yolov5/test/images/IMG_8470-3-_jpg.rf.171605ee6cdffb5b835d8b37452490f1.jpg: 640x640 1 healthy chilli leaf, 37.8ms
# image 156/240 /kaggle/working/yolov5/test/images/IMG_8478_jpg.rf.4bbbbe5a6267c2572b71f04e9fe33558.jpg: 640x640 1 healthy chilli leaf, 37.7ms
# image 157/240 /kaggle/working/yolov5/test/images/IMG_8479_jpg.rf.3bcbcf1a832b6528b620cb660b08aa08.jpg: 640x640 1 healthy chilli leaf, 37.7ms
# image 158/240 /kaggle/working/yolov5/test/images/IMG_8482-3-_jpg.rf.bbfaee6614a60d216196501ddcfc7005.jpg: 640x640 1 healthy chilli leaf, 37.7ms
# image 159/240 /kaggle/working/yolov5/test/images/IMG_8484_jpg.rf.797853f016942c8885bd0bc63c349414.jpg: 640x640 1 healthy chilli leaf, 37.2ms
# image 160/240 /kaggle/working/yolov5/test/images/IMG_8493-2-_jpg.rf.2cfb916c1229427b88f1bd5b40798bca.jpg: 640x640 1 healthy chilli leaf, 37.5ms
# image 161/240 /kaggle/working/yolov5/test/images/IMG_8495-2-_jpg.rf.4738c083a6ff2edf9ef6a220c8795613.jpg: 640x640 1 healthy chilli leaf, 37.5ms
# image 162/240 /kaggle/working/yolov5/test/images/IMG_8507_jpg.rf.26ce18cd39aea05a403ff0bba41307b4.jpg: 640x640 1 healthy chilli leaf, 37.4ms
# image 163/240 /kaggle/working/yolov5/test/images/IMG_8508_jpg.rf.9e0af5cf412d90c7658d8f2812a345d8.jpg: 640x640 1 healthy chilli leaf, 37.5ms
# image 164/240 /kaggle/working/yolov5/test/images/IMG_9079_jpg.rf.40d50537b7767cff54e47caf433292ea.jpg: 640x640 1 eggplant healthy fruit, 37.6ms
# image 165/240 /kaggle/working/yolov5/test/images/IMG_9084-3-_jpg.rf.2e2c0feebb29a5e6c6824e4b80895653.jpg: 640x640 1 eggplant healthy fruit, 37.6ms
# image 166/240 /kaggle/working/yolov5/test/images/IMG_9089-1-_jpg.rf.05fe798e27c93dff3920f7871b164993.jpg: 640x640 1 eggplant healthy fruit, 37.7ms
# image 167/240 /kaggle/working/yolov5/test/images/IMG_9095-1-_jpg.rf.1135fa59479636aa2ae5839faa8b2e45.jpg: 640x640 1 eggplant healthy fruit, 37.7ms
# image 168/240 /kaggle/working/yolov5/test/images/IMG_9095_jpg.rf.36d3a9189b5e7a2520364b6a3e794eaa.jpg: 640x640 1 eggplant healthy fruit, 37.8ms
# image 169/240 /kaggle/working/yolov5/test/images/IMG_9096-3-_jpg.rf.faf00be141fa0829042f0c30d2f730a2.jpg: 640x640 1 eggplant healthy fruit, 37.8ms
# image 170/240 /kaggle/working/yolov5/test/images/IMG_9103-1-_jpg.rf.d156472b3f6d22fff4cbb19d2e61f253.jpg: 640x640 1 eggplant healthy fruit, 37.7ms
# image 171/240 /kaggle/working/yolov5/test/images/IMG_9104_jpg.rf.4847688fcce784e2b04eeecc6f016880.jpg: 640x640 1 eggplant healthy fruit, 37.7ms
# image 172/240 /kaggle/working/yolov5/test/images/IMG_9110-2-_jpg.rf.bf675171d39bca814bb169a1bddbbd5b.jpg: 640x640 1 eggplant healthy fruit, 37.6ms
# image 173/240 /kaggle/working/yolov5/test/images/This-eggplant-is-too-far-gone-but-smaller-brown-and-orange-skin-patches-can-be-OK_jpg.rf.585df341bb4eef5d50b3c601e601f60b.jpg: 640x640 1 eggplant fuit rot, 37.7ms
# image 174/240 /kaggle/working/yolov5/test/images/_157_-removebg-preview-4-_jpg.rf.8d49fe7576661cdd46470bf700feec08.jpg: 640x640 1 eggplant cercospora leaf spot, 37.6ms
# image 175/240 /kaggle/working/yolov5/test/images/_157_-removebg-preview-5-_jpg.rf.fbb99db994e74299eedc6ec2176907b7.jpg: 640x640 1 eggplant cercospora leaf spot, 37.5ms
# image 176/240 /kaggle/working/yolov5/test/images/_158_-removebg-preview-5-_jpg.rf.a5a51054c56d49b3f2f120ba66879b89.jpg: 640x640 1 eggplant cercospora leaf spot, 37.6ms
# image 177/240 /kaggle/working/yolov5/test/images/a1f6fda4-d03d-493d-b4f4-14098f1e2c57___UF-GRC_BS_Lab-Leaf-1114_JPG.rf.1eacdd85a409e77340fee860a4339261.jpg: 640x640 1 tomato bacterial spot, 1 tomato late blight leaf, 37.4ms
# image 178/240 /kaggle/working/yolov5/test/images/a20bd77c-4ecf-473c-89aa-329b1719fbe1___RS_Erly-B-7639_JPG.rf.43465c7be52a84002534ec4eee10e69e.jpg: 640x640 1 tomato late blight leaf, 37.5ms
# image 179/240 /kaggle/working/yolov5/test/images/a3f46db1-a45c-4afa-9c80-86b4169459b9___GCREC_Bact-Sp-5754_JPG.rf.107371458ab31a627727051c67797d8e.jpg: 640x640 1 tomato bacterial spot, 37.8ms
# image 180/240 /kaggle/working/yolov5/test/images/a442ef7e-3c93-45d9-85c0-5fa66fe32bb8___RS_Erly-B-7504_JPG.rf.04a2375c378d562b793d0919a6dcc1cf.jpg: 640x640 1 tomato late blight leaf, 37.7ms
# image 181/240 /kaggle/working/yolov5/test/images/a6041f09-68f2-4865-ad78-81018617d2c4___RS_Erly-B-6450_JPG.rf.dcd469430cca50d1a1db3c42ae68955a.jpg: 640x640 1 tomato late blight leaf, 37.5ms
# image 182/240 /kaggle/working/yolov5/test/images/a7af4903-9aae-45be-990d-adfca4510cfa___GCREC_Bact-Sp-5872_JPG.rf.f72d82b53eeb54a66ae828051a284f7a.jpg: 640x640 1 tomato bacterial spot, 37.7ms
# image 183/240 /kaggle/working/yolov5/test/images/a8ed156ce3bbf8ce7c3be13214b29374-5-edit2_jpg.rf.ed503f59ed3ee9c7a260b11a5afa4362.jpg: 640x640 2 eggplant healthy leafs, 37.6ms
# image 184/240 /kaggle/working/yolov5/test/images/a8ed156ce3bbf8ce7c3be13214b29374-5-edit_jpg.rf.15d8758412d94630bc1da1ccef49e15f.jpg: 640x640 1 eggplant healthy leaf, 37.7ms
# image 185/240 /kaggle/working/yolov5/test/images/a9d50751-cfaf-4743-93d9-25207fadb580___GCREC_Bact-Sp-3654_JPG.rf.3181b56830ad0cdc46eca5d216cf8c5b.jpg: 640x640 1 tomato bacterial spot, 37.7ms
# image 186/240 /kaggle/working/yolov5/test/images/ac6a9426-691d-46f4-941a-6637659bbbf7___RS_Erly-B-9394_JPG.rf.63fba5ecbaaf5abdf248432f7d2a1c1c.jpg: 640x640 1 tomato late blight leaf, 37.7ms
# image 187/240 /kaggle/working/yolov5/test/images/alternariasolani121_JPG.rf.acadf0daba48c8ce84824a94fe31982d.jpg: 640x640 1 potato alternaria solani leaf, 37.7ms
# image 188/240 /kaggle/working/yolov5/test/images/alternariasolani131_JPG.rf.847ddba45f733e58a4a327354f6fb065.jpg: 640x640 1 potato alternaria solani leaf, 37.7ms
# image 189/240 /kaggle/working/yolov5/test/images/alternariasolani133_JPG.rf.19f9ba11aae3be06fd8a8d9e63a58005.jpg: 640x640 1 potato alternaria solani leaf, 37.7ms
# image 190/240 /kaggle/working/yolov5/test/images/alternariasolani167_JPG.rf.e807229de64b6a5ebb6cad40227fb75e.jpg: 640x640 1 potato alternaria solani leaf, 37.7ms
# image 191/240 /kaggle/working/yolov5/test/images/alternariasolani171_JPG.rf.9d73fa06d6d479ef077b8bdda831f6fd.jpg: 640x640 1 potato alternaria solani leaf, 37.8ms
# image 192/240 /kaggle/working/yolov5/test/images/alternariasolani174_JPG.rf.d32dd9f89773ba2de3bf517f42a2dde3.jpg: 640x640 1 potato alternaria solani leaf, 37.7ms
# image 193/240 /kaggle/working/yolov5/test/images/alternariasolani196_JPG.rf.e7b3160124ca3f753f8ea86abdf3387e.jpg: 640x640 1 potato alternaria solani leaf, 37.5ms
# image 194/240 /kaggle/working/yolov5/test/images/alternariasolani214_JPG.rf.a3ef990e918d18c5822ed78901d66cb5.jpg: 640x640 1 potato alternaria solani leaf, 37.8ms
# image 195/240 /kaggle/working/yolov5/test/images/alternariasolani216_JPG.rf.3895829fed552823d168e35fb64856ab.jpg: 640x640 1 potato alternaria solani leaf, 37.6ms
# image 196/240 /kaggle/working/yolov5/test/images/alternariasolani218_JPG.rf.fbe4da27bb9f4ac27507b762e5b9ac0e.jpg: 640x640 1 potato alternaria solani leaf, 37.7ms
# image 197/240 /kaggle/working/yolov5/test/images/alternariasolani236_JPG.rf.71744870e8749e55b7e43c4d1c4e2dd1.jpg: 640x640 1 potato alternaria solani leaf, 37.7ms
# image 198/240 /kaggle/working/yolov5/test/images/alternariasolani268_JPG.rf.4755c2835ff0bbe752e081b95a6e78b7.jpg: 640x640 1 potato alternaria solani leaf, 37.7ms
# image 199/240 /kaggle/working/yolov5/test/images/alternariasolani282_JPG.rf.811945d04eb2bb02b1cd79d00057e897.jpg: 640x640 1 potato alternaria solani leaf, 37.6ms
# image 200/240 /kaggle/working/yolov5/test/images/alternariasolani62_JPG.rf.fa11ae8112ea14bb2603df03c8abbd13.jpg: 640x640 1 potato alternaria solani leaf, 37.7ms
# image 201/240 /kaggle/working/yolov5/test/images/alternariasolani71_JPG.rf.be004a2d7b9b5115d6d14635fd592e6e.jpg: 640x640 1 potato alternaria solani leaf, 37.7ms
# image 202/240 /kaggle/working/yolov5/test/images/alternariasolani93_JPG.rf.c3a6fb695b391b6d6169f012d1227895.jpg: 640x640 1 potato alternaria solani leaf, 37.7ms
# image 203/240 /kaggle/working/yolov5/test/images/anthracnose-in-peppers-500x50edit4_jpg.rf.d83db1fdc2ee36b569a8565153c52b72.jpg: 640x640 2 chilli antracnoses, 37.7ms
# image 204/240 /kaggle/working/yolov5/test/images/b-2-_jpg.rf.0cedfc4fb6013f358a8dd761cbbca472.jpg: 640x640 1 eggplant healthy fruit, 37.7ms
# image 205/240 /kaggle/working/yolov5/test/images/cf198a15ace29cef44dcf03e1f850fdb_1c6d29ef-3e9c-4fec-a383-e145dbe9c8d4_394x-300x300_jpg.rf.b1f7c230d6c8003af6a7ca3df11138b0.jpg: 640x640 1 eggplant healthy fruit, 37.7ms
# image 206/240 /kaggle/working/yolov5/test/images/ee-removebg-preview-5-edit_jpg.rf.604329850646d150f389bc85db5c9311.jpg: 640x640 1 eggplant healthy leaf, 37.7ms
# image 207/240 /kaggle/working/yolov5/test/images/fwfewf-removebg-preview-5-_jpg.rf.dbc102a62beee9e83456b191fd896d8b.jpg: 640x640 1 eggplant healthy leaf, 37.8ms
# image 208/240 /kaggle/working/yolov5/test/images/gedit_jpg.rf.8cb6f80930247436b723234c2eb0a00d.jpg: 640x640 5 chilli antracnoses, 37.7ms
# image 209/240 /kaggle/working/yolov5/test/images/hyrtedit4_jpg.rf.c0185719a58852eb34a4c09f45e7ad52.jpg: 640x640 3 chilli antracnoses, 37.7ms
# image 210/240 /kaggle/working/yolov5/test/images/ijms-19-03122-g001a-removebg-preview-Copy-2-edit2_jpg.rf.42d9949d8011a4a376130f3d0f26dbb9.jpg: 640x640 1 chilli antracnose, 37.6ms
# image 211/240 /kaggle/working/yolov5/test/images/images-1-_jpg.rf.84ad1cc4e7cfedcdd06abc41e30d38ea.jpg: 640x640 1 chilli antracnose, 37.7ms
# image 212/240 /kaggle/working/yolov5/test/images/images__1_-removebg-preview-2-Copyedit3_jpg.rf.67dadd6c4d532f941774394addd28358.jpg: 640x640 1 chilli antracnose, 37.4ms
# image 213/240 /kaggle/working/yolov5/test/images/images__1_-removebg-preview-2-Copyedit4_jpg.rf.3d0b28d80981fa72d3488229d74358f8.jpg: 640x640 1 chilli antracnose, 37.4ms
# image 214/240 /kaggle/working/yolov5/test/images/images__1_-removebg-preview-3-Copyedit4_jpg.rf.bfd92384904212d1d47f99c43c51d57e.jpg: 640x640 1 chilli antracnose, 37.3ms
# image 215/240 /kaggle/working/yolov5/test/images/images__1_-removebg-previewedit3_jpg.rf.d9768138caa35ba882c8b34ae54a9371.jpg: 640x640 1 chilli antracnose, 37.6ms
# image 216/240 /kaggle/working/yolov5/test/images/maxresdefault-2-_jpg.rf.e93942931d08d12c1ba0f581410d3ebb.jpg: 640x640 1 eggplant fuit rot, 37.6ms
# image 217/240 /kaggle/working/yolov5/test/images/maxresdefault-2-_jpg.rf.ffec7836f537c84ca3c4fbcd0fa71751.jpg: 640x640 1 eggplant fuit rot, 37.6ms
# image 218/240 /kaggle/working/yolov5/test/images/maxresdefaultedit_jpg.rf.aa3057380d97caf62731a1aa3381276f.jpg: 640x640 4 chilli antracnoses, 37.8ms
# image 219/240 /kaggle/working/yolov5/test/images/phytopthora215_jpg.rf.ccfc87c88ee93fe28c4f4f96be145105.jpg: 640x640 1 potato pythopthora infestans leaf, 37.7ms
# image 220/240 /kaggle/working/yolov5/test/images/phytopthora219_jpg.rf.99e276a333f4165cd34df2ef44b0a2f0.jpg: 640x640 1 potato pythopthora infestans leaf, 37.6ms
# image 221/240 /kaggle/working/yolov5/test/images/phytopthora224_jpg.rf.5ef0fc2519b70bc3a670619bb1d45fa2.jpg: 640x640 1 potato pythopthora infestans leaf, 37.7ms
# image 222/240 /kaggle/working/yolov5/test/images/phytopthora263_jpg.rf.4150960b103f396ccfe113603cc4fc78.jpg: 640x640 1 potato pythopthora infestans leaf, 37.8ms
# image 223/240 /kaggle/working/yolov5/test/images/phytopthora329_jpg.rf.f408e95441651dc7e6628e02afd84a33.jpg: 640x640 1 potato pythopthora infestans leaf, 37.7ms
# image 224/240 /kaggle/working/yolov5/test/images/phytopthora334_jpg.rf.a16ee2e0a2952dc5d62a48cac901a839.jpg: 640x640 1 potato pythopthora infestans leaf, 37.8ms
# image 225/240 /kaggle/working/yolov5/test/images/phytopthora33_jpg.rf.1b442fb3b6224a40e47dc42e9a9092e0.jpg: 640x640 1 potato pythopthora infestans leaf, 37.7ms
# image 226/240 /kaggle/working/yolov5/test/images/phytopthora350_jpg.rf.40b2df36e8bf3faf6e5a3da9d3968533.jpg: 640x640 1 potato pythopthora infestans leaf, 37.8ms
# image 227/240 /kaggle/working/yolov5/test/images/phytopthora353_jpg.rf.1faf4567f16ac6c1561059f1ead0f258.jpg: 640x640 1 potato pythopthora infestans leaf, 37.6ms
# image 228/240 /kaggle/working/yolov5/test/images/phytopthora357_jpg.rf.e941bd208dafb0224fd624cd53ad72ca.jpg: 640x640 1 potato pythopthora infestans leaf, 37.7ms
# image 229/240 /kaggle/working/yolov5/test/images/phytopthora365_jpg.rf.37ff40582f34664b638653859a0a8d83.jpg: 640x640 1 potato pythopthora infestans leaf, 37.7ms
# image 230/240 /kaggle/working/yolov5/test/images/phytopthora368_jpg.rf.d33177bf58bda49f86e162bb8835722f.jpg: 640x640 1 potato pythopthora infestans leaf, 37.7ms
# image 231/240 /kaggle/working/yolov5/test/images/phytopthora371_jpg.rf.4e0f20d254f2e808dde6392a99da6726.jpg: 640x640 1 potato pythopthora infestans leaf, 37.7ms
# image 232/240 /kaggle/working/yolov5/test/images/phytopthora397_jpg.rf.de4b1bc697f68b5c65dd2f6dd98d7133.jpg: 640x640 1 potato pythopthora infestans leaf, 37.5ms
# image 233/240 /kaggle/working/yolov5/test/images/phytopthora409_jpg.rf.6788ffda5f1531f1121cd5ee4432d9e6.jpg: 640x640 1 potato pythopthora infestans leaf, 37.2ms
# image 234/240 /kaggle/working/yolov5/test/images/pmdg_106759edit4-1-_jpg.rf.9b07d923793d819333a8db46aad81a6d.jpg: 640x640 1 chilli antracnose, 37.7ms
# image 235/240 /kaggle/working/yolov5/test/images/r-4-_jpg.rf.1ac208ac6db3e9f76d0d2d0a132b034a.jpg: 640x640 1 eggplant fuit rot, 37.6ms
# image 236/240 /kaggle/working/yolov5/test/images/rret-2-_jpg.rf.1881cddce5d4855013262859dee84bae.jpg: 640x640 1 eggplant fuit rot, 37.7ms
# image 237/240 /kaggle/working/yolov5/test/images/stock-photo-decayed-rotten-eggplant-old-vegetable-with-mold-isolated-on-a-white-background-1893067546_jpg.rf.6b9748ba52b582aadce93742020a63ca.jpg: 640x640 1 eggplant fuit rot, 37.7ms
# image 238/240 /kaggle/working/yolov5/test/images/stock-photo-old-rotten-eggplant-lying-on-the-grass-near-the-trash-discarded-old-rotting-eggplant-2138852055-2-_jpg.rf.fc02658d5145a648eee18d98a44e2ded.jpg: 640x640 2 eggplant fuit rots, 37.7ms
# image 239/240 /kaggle/working/yolov5/test/images/stock-photo-old-rotten-eggplant-lying-on-the-grass-near-the-trash-discarded-old-rotting-eggplant-2140392875-1-_jpg.rf.d01a32143de7bd5b9a59883013f7489f.jpg: 640x640 2 eggplant fuit rots, 37.7ms
# image 240/240 /kaggle/working/yolov5/test/images/wwrf_jpg.rf.9686af7e5b43cb256034c423cf71dadb.jpg: 640x640 4 eggplant fuit rots, 37.8ms
# Speed: 0.5ms pre-process, 38.2ms inference, 2.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5_train/detect_test

# %%
def read_images(dirpath):
  images = []
  for img_filename in os.listdir(dirpath):
    images.append(mpimg.imread(f"{dirpath}/{img_filename}"))
  return images

# %%
def label_test_images(test_images_path, test_labels_path, classes):
  test_images = os.listdir(test_images_path)
  labeled_images = []

  for idx, test_image_filename in enumerate(test_images):
    image = cv2.imread(f"{test_images_path}/{test_image_filename}")
    
    x_shape, y_shape = image.shape[1], image.shape[0]

    test_label_filename = f"{test_image_filename[:-4]}.txt"
    
    with open(f"{test_labels_path}/{test_label_filename}", "r") as f:
      lines = f.readlines()

      for line in lines:
        # Parse line
        box = line.split()
        class_idx = box[0]
        
        class_name = names[int(class_idx)]
        x_center, y_center, box_w, box_h = int(float(box[1])*x_shape), int(float(box[2])*y_shape), int(float(box[3])*x_shape), int(float(box[3])*y_shape)
        x1, y1, x2, y2 = x_center-int(box_w/2), y_center-int(box_h/2), x_center+int(box_w/2), y_center+int(box_h/2)

        cv2.rectangle(image, (x1, y1), (x2, y2), (0, 0, 255), 3)
        cv2.putText(image, class_name, (x1, y1), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 3)

    labeled_images.append(image)

  return labeled_images

# %%
detect_path = f"{PROJECT_NAME}/detect_test"
test_images_path = f"test/images"
test_labels_path = f"test/labels"

detected_images = read_images(detect_path)
test_labeled_images = label_test_images(test_images_path, test_labels_path, classes=names)

stacked_images = [np.hstack([detected_images[idx], test_labeled_images[idx]]) for idx in range(len(detected_images))]

# %%
for image in stacked_images:
  fig = plt.figure(figsize=(40, 15))
  ax1 = fig.add_subplot(2,2,1)
  ax1.imshow(image)

# %% [markdown]
# # Save model

# %% [markdown]
# To save your model just download best.pt file from PROJECT_FOLDER -> feature_extraction (your best) -> weights -> best.pt
#
# File best.pt will be used to load it in your project to predict.
